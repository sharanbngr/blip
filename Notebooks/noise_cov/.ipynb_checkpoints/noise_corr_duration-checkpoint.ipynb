# %%
import numpy as np
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12,8)
matplotlib.rcParams.update({'font.size': 24})
import matplotlib.pyplot as plt
from scipy.signal import butter, sosfiltfilt, welch, tukey

# %%
def psd_noise(freqs, plot=0):
    
    data = np.loadtxt('/home/sharan.banagiri/longpe/bilong/IO/aLIGO_O2ASD.txt')
    f_req, psd_req = data[:, 0], data[:, 1]**2
    
    psd = np.interp(freqs, f_req, np.log10(psd_req))
    psd = 10**psd
    
    
    if plot:
        plt.loglog(freqs, psd, label='psd')
        plt.loglog(f_req, psd_req, label='psd from file')
        plt.legend()
        plt.xlabel('freq Hz')
        plt.ylabel('PSD 1/Hz')
    else:
        return psd
    
## --------------------------------
psd_noise(freqs=np.arange(0, 200, 1), plot=1)

# %% [markdown]
# The noise correlation is defined as (Eq 5.107 Bendot & Piersol)
#
# $T_n = \frac{2}{R_{xx}(0)}\int_0^{\infty} d \tau | R_{xx}(\tau)|$
#
# We can calculate the time-domain auto-correlation function $R_{xx}$ using the real-ifft of the one-sided PSD $G_{xx}(f)$ (Eq 5.35 Bendot & Piersol)
#
# $R_{xx} (\tau) = \int_0^{\infty} df G_{xx}(f) \cos(2\pi f \tau) $

# %%
def noi_corr_dur(fs=2048, dur=100, **kwargs):
    
    # Number of data points in the time series
    N = int(fs*dur)
    
    # We will make an array of the desired frequencies
    fout = np.fft.rfftfreq(N, 1.0/fs)
    
    Sh = psd_noise(fout, plot=0)
    
    
    if len(kwargs) > 0:
        fmin = float(kwargs['fmin'])
        fmax = float(kwargs['fmax'])
    
        Sh[fout < fmin] = 0
        Sh[fout > fmax] = 0
        
    
    Rxx = np.fft.irfft(Sh)
    
    Rxx_0 = Rxx[0]
    
    tau_vals = np.arange(N)/fs
    dtau = tau_vals[1] - tau_vals[0]
    
    Tn = 2*np.trapz(np.abs(Rxx), x = tau_vals)/Rxx_0
    
    print('The noise correlation duration is ' + str(Tn))
    
    
        
    plt.loglog(tau_vals[0:int(0.5*tau_vals.size)], np.abs(Rxx[0:int(0.5*tau_vals.size)])/Rxx_0, linewidth=1)
    plt.xlabel('$\\tau$ in s')
    plt.axvline(4, color='r', linewidth=1)
    plt.ylabel('$\\dfrac{|R_{xx}( \\tau )| }{ R_{xx}(0)}$')
    plt.savefig('auto_corr.pdf', dpi=150, bbox_inches='tight')

# %%
noi_corr_dur(fs=2048, dur=1000)
# Out:
# The noise correlation duration is 0.3382809872975921

# %%
noi_corr_dur(fs=2048, dur=1000, fmin=30, fmax=1000)
# Out:
# The noise correlation duration is 0.02057443400097687

# %%
noi_corr_dur(fs=2048, dur=1000, fmin=400, fmax=750)
# Out:
# The noise correlation duration is 0.02497250379298053

# %%
noi_corr_dur(fs=2048, dur=200)
# Out:
# The noise correlation duration is 0.338280323077399

# %%
noi_corr_dur(fs=2048, dur=200, fmin=400, fmax=750)
# Out:
# The noise correlation duration is 0.022216672510144985

# %%
noi_corr_dur(fs=2048, dur=4)
# Out:
# The noise correlation duration is 0.3274788119070628

# %%
noi_corr_dur(fs=2048, dur=20)
# Out:
# The noise correlation duration is 0.3382118208948315
